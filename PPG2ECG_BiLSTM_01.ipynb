# %% [markdown]
# <a href="https://colab.research.google.com/github/amalazimroshan/PPG2ECG_BiLSTM/blob/main/PPG2ECG_BiLSTM_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy import signal
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pylab as pl

# %%
def extract(ppg,fs):
  fn = fs/2
  fl = 0.5
  fh = 10
  window_peak = int(fs * 0.111)
  window_beat = int(fs * 0.667)
  beta = 0.02

  b, a = signal.cheby2(2,20,[fl/fn,fh/fn],'bandpass')

# %%
f0 = 0.1
b,a = signal.cheby1(4,10,0.1*2)
sos = signal.cheby1(4,10,0.1*2 ,output='sos')

w,h = signal.freqz(b,a)
pl.plot(w/np.pi,20*np.log10(np.abs(h)))
